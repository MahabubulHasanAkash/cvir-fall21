# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.cifar10.load_data()
print(X_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
accuracy = []
temp_acc = []
man = euc = 0
man_distance = []
euc_distance = []
for k in range(1, 101):
  print("k: ", k)
  for fold in range(5):
    validationX = X_train[fold*10000:(fold+1)*10000]
    validationY = Y_train[fold*10000:(fold+1)*10000]
    trainX = np.concatenate((X_train[:fold*10000], X_train[(fold+1)*10000:]), axis = 0)
    trainY = np.concatenate((Y_train[:fold*10000], Y_train[(fold+1)*10000:]), axis = 0)
    for i in range(len(validationX)):
      for j in range(len(trainX)):
        l1 = np.sum(np.absolute(np.subtract(validationX[i], trainX[j])))
        l2 = np.sqrt(np.sum((validationX[i] - trainX[j])**2))
        man_distance.append([l1, trainY[j][0]])
        euc_distance.append([l2, trainY[j][0]])
        man_distance = np.array(man_distance)
        man_distance = man_distance[man_distance[:, 0].argsort()]
        euc_distance = np.array(euc_distance)
        euc_distance = euc_distance[euc_distance[:, 0].argsort()]
        values = man_distance[:k, 1]
        mfv = np.argmax(np.bincount(values.astype('int32')))
        if most_frequent_value == validationY[i]:
        man += 1
        values = euc_distance[:k, 1]
        mfv = np.argmax(np.bincount(values.astype('int32')))
      if most_frequent_value == validationY[i]:
        euc += 1
      if i == 100:
        break 
    temp_acc.append([nam/100, euc/100])
    accuracy.append([temp_acc, k])
print(accuracy)
# Out:
# k:  1
# k:  2
# k:  3
# k:  4
# k:  5
# k:  6
# k:  7
# k:  8
# k:  9
# k:  10
# k:  11
# k:  12
# k:  13
# k:  14
# k:  15
# k:  16
# k:  17
# k:  18
# k:  19
# k:  20
# k:  21
# k:  22
# k:  23
# k:  24
# k:  25
# k:  26
# k:  27
# k:  28
# k:  29
# k:  30
# k:  31
# k:  32
# k:  33
# k:  34
# k:  35
# k:  36
# k:  37
# k:  38
# k:  39
# k:  40
# k:  41
# k:  42
# k:  43
# k:  44
# k:  45
# k:  46
# k:  47
# k:  48
# k:  49
# k:  50
# k:  51
# k:  52
# k:  53
# k:  54
# k:  55
# k:  56
# k:  57
# k:  58
# k:  59
# k:  60
# k:  61
# k:  62
# k:  63
# k:  64
# k:  65
# k:  66
# k:  67
# k:  68
# k:  69
# k:  70
# k:  71
# k:  72
# k:  73
# k:  74
# k:  75
# k:  76
# k:  77
# k:  78
# k:  79
# k:  80
# k:  81
# k:  82
# k:  83
# k:  84
# k:  85
# k:  86
# k:  87
# k:  88
# k:  89
# k:  90
# k:  91
# k:  92
# k:  93
# k:  94
# k:  95
# k:  96
# k:  97
# k:  98
# k:  99
# k:  100
# [[[[0.16, 0.15], [0.24, 0.17], [0.16, 0.11], [0.21, 0.19], [0.1, 0.13]], 1], [[[0.16, 0.1], [0.18, 0.2], [0.16, 0.12], [0.16, 0.16], [0.14, 0.13]], 2], [[[0.24, 0.1], [0.23, 0.15], [0.13, 0.15], [0.16, 0.11], [0.12, 0.15]], 3], [[[0.16, 0.14], [0.26, 0.24], [0.14, 0.14], [0.12, 0.2], [0.14, 0.17]], 4], [[[0.1,
.18], [0.15, 0.16], [0.2, 0.19], [0.21, 0.23]], 32], [[[0.14, 0.13], [0.22, 0.18], [0.14, 0.15], [0.19, 0.14], [0.23, 0.2]], 33], [[[0.14, 0.13], [0.22, 0.17], [0.13, 0.16], [0.17, 0.13], [0.22, 0.23]], 34], [[[0.14, 0.13], [0.23, 0.17], [0.16, 0.15], [0.15, 0.15], [0.21, 0.25]], 35], [[[0.14, 0.13], [0.21, 0.16], [0.15, 0.15], [0.15, 0.17], [0.2, 0.25]], 36], [[[0.15, 0.13], [0.23, 0.15], [0.16, 0.15], [0.15, 0.18], [0.21, 0.22]], 37], [[[0.15, 0.12], [0.22, 0.18], [0.17, 0.13], [0.15, 0.17], [0.21, 0.24]], 38], [[[0.14, 0.13], [0.23, 0.17], [0.14, 0.13], [0.16, 0.18], [0.23, 0.25]], 39], [[[0.13, 0.13], [0.24, 0.16], [0.15, 0.13], [0.15, 0.18], [0.21, 0.26]], 40], [[[0.14, 0.13], [0.21, 0.19], [0.13, 0.12], [0.14, 0.19], [0.21, 0.24]], 41], [[[0.14, 0.12], [0.22, 0.2], [0.11, 0.11], [0.14, 0.19], [0.22, 0.23]], 42], [[[0.14, 0.12], [0.2, 0.23], [0.12, 0.1], [0.14, 0.18], [0.23, 0.27]], 43], [[[0.14, 0.13], [0.24, 0.22], [0.09, 0.1], [0.14, 0.18], [0.24, 0.25]], 44], [[[0.13, 0.13], [0.22, 0.21], [0.1, 0.1], [0.13, 0.2], [0.24, 0.25]], 45], [[[0.15, 0.14], [0.21, 0.19], [0.09, 0.09], [0.15, 0.2], [0.24, 0.26]], 46], [[[0.14, 0.14], [0.21, 0.21], [0.09, 0.1], [0.16, 0.2], [0.24, 0.26]], 47], [[[0.15, 0.13], [0.2, 0.2], [0.09, 0.1], [0.15, 0.19], [0.24, 0.23]], 48], [[[0.13, 0.15], [0.21, 0.2], [0.1, 0.11], [0.15, 0.2], [0.23, 0.26]], 49], [[[0.12, 0.16], [0.21, 0.19], [0.12, 0.12], [0.15, 0.19], [0.23, 0.26]], 50], [[[0.12, 0.15], [0.21, 0.19], [0.12, 0.15], [0.16, 0.2], [0.21, 0.27]], 51], [[[0.12, 0.16], [0.21, 0.19], [0.12, 0.15], [0.17, 0.2], [0.22, 0.28]], 52],  ...

# %%
avg1 = []
avg2 = []
k = np.array(accuracy,dtype=object,)[:,1]
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.title('Manhattan')
for i in range(len(accuracy)):
  a = np.full((5), i+1, dtype=int)
  l1 = np.array(accuracy[i][0])[:,0]
  avg1.append(np.average(l1))
  plt.plot(a, l1, 'o-')
plt.plot(k, avg1, 'o-')
plt.xlabel('k')
plt.ylabel('cross-validation accuracy')
plt.subplot(1,2,2)
plt.title('Euclidean')
for i in range(len(accuracy)):
  a = np.full((5), i+1, dtype=int)
  l2 = np.array(accuracy[i][0])[:,1]
  avg2.append(np.average(l2))
  plt.plot(a, l2, 'o-')
plt.plot(k, avg2, 'o-')
plt.xlabel('k')
plt.ylabel('cross-validation accuracy')
plt.show()
